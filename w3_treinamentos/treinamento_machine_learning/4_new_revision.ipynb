# %% [markdown]
# ### Importa pandas para trabalhar com dados em formato de tabela

# %%
import pandas as pd

# %% [markdown]
# ### Importa o modelo LinearRegression, usado para aprender uma relação entre números

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Cria uma pequena tabela de treino
# ### A coluna "horas_estudo" representa quantas horas uma pessoa estudou
# ### A coluna "nota" representa a nota que essa pessoa tirou

# %%
dados = {
    "horas_estudo": [1, 2, 3, 4, 5, 6, 7, 8],
    "nota": [50, 55, 65, 70, 75, 85,90,9.5]
}

# %% [markdown]
# ### Transforma o dicionário em um DataFrame do pandas

# %%
df = pd.DataFrame(dados)

# %% [markdown]
# ### Mostra os dados usados para treinar o modelo

# %%
df
# Out:
#    horas_estudo  nota
# 0             1  50.0
# 1             2  55.0
# 2             3  65.0
# 3             4  70.0
# 4             5  75.0
# 5             6  85.0
# 6             7  90.0
# 7             8   9.5

# %% [markdown]
# ### Separa a coluna de entrada, ou seja, aquilo que o modelo vai usar para aprender
# ### O X precisa ser uma tabela, por isso usamos dois colchetes: [["horas_estudo"]]

# %%
X = df[["horas_estudo"]]

# %% [markdown]
# ### Separa a coluna de saída, ou seja, aquilo que o modelo deve prever
# ### O y é a resposta correta durante o treinamento

# %%
y = df['nota']

# %% [markdown]
# ### Cria o modelo de Machine Learning

# %%
modelo = LinearRegression()

# %% [markdown]
# ### Treina o modelo usando as horas de estudo e as notas reais

# %%
modelo.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Cria uma nova tabela com uma quantidade de horas que o modelo ainda não viu

# %%
novo_aluno = pd.DataFrame({
    'horas_estudo':[9]
})

# %% [markdown]
# ### Usa o modelo treinado para prever a nota do novo aluno

# %%
previsao = modelo.predict(novo_aluno)

# %% [markdown]
# ### Mostra o resultado da previsão

# %%
f"Se o aluno estudar 7 horas, a nota prevista é: {previsao[0]:.1f}"
# Out:
# 'Se o aluno estudar 7 horas, a nota prevista é: 60.1'

# %%
f"Joaquim, a nota prevista para 9 horas de estudo é: {previsao[0]:.1f}"
# Out:
# 'Joaquim, a nota prevista para 9 horas de estudo é: 60.1'
