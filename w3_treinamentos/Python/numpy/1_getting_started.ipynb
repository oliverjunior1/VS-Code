# %% [markdown]
# Now the NumPy package can be referred to as np instead of ``numpy``.

# %%
import numpy as np

# %%
x = np.array([1,2,3,4,5])

x
# Out:
# array([1, 2, 3, 4, 5])

# %%
np.__version__
# Out:
# '2.1.3'
