# %% [markdown]
# Now the Pandas package can be referred to as pd instead of pandas.

# %%
import pandas as pd

# %%
mydataset = {
    'cars':['BMW', 'Volvo', 'Ford'],
    'passings':[3,7,2]
}

# %%
myvar = pd.DataFrame(mydataset)
myvar
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.3'
