# %%
# Out:
# DADOS ORIGINAIS
#   cliente  idade          cidade  compra
# 0     Ana   25.0       São Paulo   120.5
# 1   Bruno   30.0  RIO DE JANEIRO    80.0
# 2     Ana   25.0       São Paulo   120.5
# 3   Carla    NaN        curitiba     NaN
# 4  Daniel   -8.0            None   200.0
# 5   Bruno   30.0  RIO DE JANEIRO    80.0
# 6    None   41.0        salvador   -15.0
#
# DADOS LIMPOS
#                  cliente  idade                cidade  compra
# 0                    Ana     25             São Paulo   120.5
# 1                  Bruno     30        Rio De Janeiro    80.0
# 3                  Carla     32              Curitiba   133.5
# 4                 Daniel     32  Cidade Não Informada   200.0
# 6  Cliente não informado     41              Salvador   133.5
#
# RELATÓRIO DE QUALIDADE
# Linhas duplicadas encontradas: 2
# Valores vazios antes da limpeza:
# cliente    1
# idade      1
# cidade     1
# compra     1
# dtype: int64
# Total de clientes após limpeza: 5
# ...
