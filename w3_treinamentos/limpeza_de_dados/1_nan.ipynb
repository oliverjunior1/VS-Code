# %% [markdown]
# Importar a biblioteca pandas

# %%
import pandas as pd

# %% [markdown]
# # 1. Criar dataset simples com valores nulos

# %%
dados = {
    'nome':['Ana', 'Bruno', 'Carlos', None],
    'idade':[25,30,None,40],
    'cidade':['SP', 'RJ', 'BH', 'SP']
}

# %%
df = pd.DataFrame(dados)
df
# Out:
#      nome  idade cidade
# 0     Ana   25.0     SP
# 1   Bruno   30.0     RJ
# 2  Carlos    NaN     BH
# 3    None   40.0     SP

# %% [markdown]
# # 2. Ver o dataset original

# %%
print("Original")
df
# Out:
# Original
#      nome  idade cidade
# 0     Ana   25.0     SP
# 1   Bruno   30.0     RJ
# 2  Carlos    NaN     BH
# 3    None   40.0     SP

# %% [markdown]
# # 3. Verificar valores nulos

# %%
print("\nValores nulos pos coluna:")
df.isnull().sum()
# Out:
# Valores nulos pos coluna:
# nome      1
# idade     1
# cidade    0
# dtype: int64

# %% [markdown]
# # 4. Remover linhas com qualquer valor nulo
