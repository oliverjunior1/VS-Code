# %% [markdown]
# ### Criar dataset

# %%
import pandas as pd

# %%
dados = {
    "nome":["Ana", "João", "Maria"],
    "idade":[25,40,32],
    "salario":[3500,5000,4500]
}

df = pd.DataFrame(dados)
df
# Out:
#     nome  idade  salario
# 0    Ana     25     3500
# 1   João     40     5000
# 2  Maria     32     4500
