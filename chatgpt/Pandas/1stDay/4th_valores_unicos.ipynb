# %%
import pandas as pd

# %%
cidades ={'cidade':["Goiânia", "Anápolis", "Goiânia", "Brasília", "Anápolis"]}

# %%
df = pd.DataFrame(cidades)
df
# Out:
#      cidade
# 0   Goiânia
# 1  Anápolis
# 2   Goiânia
# 3  Brasília
# 4  Anápolis

# %%
df['cidade'].unique()
# Out:
# array(['Goiânia', 'Anápolis', 'Brasília'], dtype=object)

# %% [markdown]
# # Quantidade de cada categoria

# %%
df['cidade'].value_counts()
# Out:
# cidade
# Goiânia     2
# Anápolis    2
# Brasília    1
# Name: count, dtype: int64
