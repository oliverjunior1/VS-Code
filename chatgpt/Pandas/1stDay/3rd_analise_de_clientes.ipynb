# %%
import pandas as pd

# %%
dados = {
    "nome":["Ana", "João", "Maria", "Pedro", "Carlos"],
    "idade":[25,40,32,28,50],
    "salario":[3500,5000,4500,2800,7000]
}

# %%
df = pd.DataFrame(dados)
df
# Out:
#      nome  idade  salario
# 0     Ana     25     3500
# 1    João     40     5000
# 2   Maria     32     4500
# 3   Pedro     28     2800
# 4  Carlos     50     7000

# %%
clientes_altos_salarios = df[df["salario"] > 4000]
clientes_altos_salarios
# Out:
#      nome  idade  salario
# 1    João     40     5000
# 2   Maria     32     4500
# 4  Carlos     50     7000

# %%
df.sort_values("salario")
# Out:
#      nome  idade  salario
# 3   Pedro     28     2800
# 0     Ana     25     3500
# 2   Maria     32     4500
# 1    João     40     5000
# 4  Carlos     50     7000
