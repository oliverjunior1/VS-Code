# %%
import pandas as pd

# %%
dados = {
    'nome':['Ana', 'João', 'Maria', 'Pedro'],
    'salario':[3500,5000,4500,2800]
}

df = pd.DataFrame(dados)
df
# Out:
#     nome  salario
# 0    Ana     3500
# 1   João     5000
# 2  Maria     4500
# 3  Pedro     2800
