# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
vendas = [1000,1500,1300,1800,2200]

# %%
plt.plot(vendas)

plt.title("Evolução das vendas")
plt.xlabel('Período')
plt.ylabel("Valor")
# Out:
# Text(0, 0.5, 'Valor')
