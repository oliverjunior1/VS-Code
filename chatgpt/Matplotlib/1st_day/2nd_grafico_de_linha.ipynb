# %%
import matplotlib.pyplot as plt

# %%
meses = ["Jan", "Fev", "Mar", "Abr", "Mai", "Jun"]
vendas = [1200,1500,1400,1800,2100,2500]

# %%
plt.plot(meses, vendas)

# %%
plt.plot(meses, vendas)

plt.title("Evolução das vendas")
plt.xlabel("Mês")
plt.ylabel("Valor das vendas")

plt.grid()
