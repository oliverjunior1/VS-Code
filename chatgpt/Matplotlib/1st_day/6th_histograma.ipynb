# %%
import matplotlib.pyplot as plt

# %%
idades = [18,20,21,22,23,25,26,27,28,30,31,32,35,36,40]

# %%
plt.hist(idades)

plt.title("Distribuição das idades")
plt.xlabel('Idade')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
plt.hist(idades, bins=5)
# Out:
# (array([4., 3., 4., 2., 2.]),
#  array([18. , 22.4, 26.8, 31.2, 35.6, 40. ]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(idades, bins=10)
# Out:
# (array([2., 2., 1., 2., 2., 2., 1., 1., 1., 1.]),
#  array([18. , 20.2, 22.4, 24.6, 26.8, 29. , 31.2, 33.4, 35.6, 37.8, 40. ]),
#  <BarContainer object of 10 artists>)
