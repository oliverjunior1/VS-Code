# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dados = {
    'produto': ['Notebook', 'Mouse', 'Teclado', 'Monitor'],
    'quantidade':[20,100,70,40],
    'preco':[3500,80,150,1200]
}

# %%
df = pd.DataFrame(dados)

# %%
df['total'] = df['quantidade'] * df['preco']
df
# Out:
#     produto  quantidade  preco  total
# 0  Notebook          20   3500  70000
# 1     Mouse         100     80   8000
# 2   Teclado          70    150  10500
# 3   Monitor          40   1200  48000

# %%
plt.bar(df['produto'], df['total'])

plt.title('Faturamento por produto')
plt.xlabel('Produto')
plt.ylabel('faturamento')
# Out:
# Text(0, 0.5, 'faturamento')
