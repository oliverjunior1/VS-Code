# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [10,20,15,30,25]

# %%
plt.plot(x, y)

# %%
meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai']
vendas = [100,150,130,180,220]

# %%
plt.plot(meses, vendas)

# %%
plt.title("Vendas por mês")
plt.plot(meses, vendas)

# %%
plt.plot(meses, vendas)
plt.title("Vendas por mês")
plt.xlabel("Mês")
plt.ylabel("Quantidade de vendas")
plt.grid()
