# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dados = {
    'produto':['Notebook', 'Mouse', 'Teclado', 'Monitor', 'Headset'],
    'vendas':[12000,5000,7000,15000,9000]
}

# %%
df = pd.DataFrame(dados)
df
# Out:
#     produto  vendas
# 0  Notebook   12000
# 1     Mouse    5000
# 2   Teclado    7000
# 3   Monitor   15000
# 4   Headset    9000

# %% [markdown]
# # Primeiro: descobrir o maior faturamento

# %%
print(df['vendas'].max())
# Out:
# 15000
