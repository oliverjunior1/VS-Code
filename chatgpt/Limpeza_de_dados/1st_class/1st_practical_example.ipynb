# %%
import pandas as pd

dados = {
    "nome": [
        "João",
        "Maria",
        "Pedro",
        "Ana",
        "Carlos"
    ],
    
    "idade": [
        32,
        28,
        None,
        29,
        None
    ],
    
    "salario": [
        3500,
        4200,
        3800,
        None,
        5000
    ]
}

df = pd.DataFrame(dados)

print("Dados:")
print(df)

print("\nValores ausentes:")
print(df.isnull().sum())
# Out:
# Dados:
#      nome  idade  salario
# 0    João   32.0   3500.0
# 1   Maria   28.0   4200.0
# 2   Pedro    NaN   3800.0
# 3     Ana   29.0      NaN
# 4  Carlos    NaN   5000.0
#
# Valores ausentes:
# nome       0
# idade      2
# salario    1
# dtype: int64
