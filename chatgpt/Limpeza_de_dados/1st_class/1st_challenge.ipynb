# %%
import pandas as pd

dados = {
    "nome": [
        "João",
        "Maria",
        "Pedro",
        "João",
        "Ana",
        "Carlos"
    ],
    
    "idade": [
        32,
        None,
        25,
        32,
        None,
        41
    ],
    
    "salario": [
        3500,
        4200,
        None,
        3500,
        2800,
        None
    ]
}

df = pd.DataFrame(dados)

# %% [markdown]
# ### Descobrir quantos valores ausentes existem.

# %%
sum_of_null =df.isnull().sum()
sum_of_null
# Out:
# nome       0
# idade      2
# salario    2
# dtype: int64
