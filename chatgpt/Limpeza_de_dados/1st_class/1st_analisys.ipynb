# %% [markdown]
# ### Vamos utilizar Pandas.

# %%
import pandas as pd

# %% [markdown]
# ### Criar o primeiro dataframe

# %%
dados = {
    'nome':['João', 'Maria', 'Pedro', 'João', 'Ana'],
    'idade':[32,28,None, 32,29],
    'cidade':['Goiânia', 'Brasilia', 'Goiânia','Goiânia','Goiânia'],
    'salario':[3500,4200,3800,3500, None]
}

df = pd.DataFrame(dados)

df
# Out:
#     nome  idade    cidade  salario
# 0   João   32.0   Goiânia   3500.0
# 1  Maria   28.0  Brasilia   4200.0
# 2  Pedro    NaN   Goiânia   3800.0
# 3   João   32.0   Goiânia   3500.0
# 4    Ana   29.0   Goiânia      NaN
