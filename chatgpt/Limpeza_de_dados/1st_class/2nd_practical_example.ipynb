# %%
import pandas as pd

dados = {
    "nome": ["João", "Maria", "Pedro", "Ana", "Carlos"],
    "idade": [32, 28, None, 29, 40]
}

df = pd.DataFrame(dados)

print("Antes:")
print(df)

media_idade = df["idade"].mean()

df["idade"] = df["idade"].fillna(media_idade)

print("\nDepois:")
print(df)
# Out:
# Antes:
#      nome  idade
# 0    João   32.0
# 1   Maria   28.0
# 2   Pedro    NaN
# 3     Ana   29.0
# 4  Carlos   40.0
#
# Depois:
#      nome  idade
# 0    João  32.00
# 1   Maria  28.00
# 2   Pedro  32.25
# 3     Ana  29.00
# 4  Carlos  40.00

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool
