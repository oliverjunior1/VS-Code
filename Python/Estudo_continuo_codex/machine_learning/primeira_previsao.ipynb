# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ### Cada pessoa possui: [idade, visitou_site]

# %%
X = [
    [20, 0],
    [25, 1],
    [35, 0],
    [40, 1],
    [50, 1],
]

# %%
# 0 = não comprou
# 1 = comprou

# %%
y = [0,0,0,1,1]
