# %% [markdown]
# ### Receita de bolo - árvore de decisão

# %% [markdown]
# ###### Objetivo:
# ###### Descobrir qual é o tipo de floresta
# ###### utilizando diversas características do terreno.
# #
# ###### Forest Cover Type
# #
# ###### Mais de 580 mil registros
# ###### 54 variáveis

# %% [markdown]
# ### Passo 1 - Importar as bibliotecas

# %% [markdown]
# 1. Manipulação de dados

# %% [markdown]
# 2. Dividir treino e teste

# %% [markdown]
# 3. Modelo árvore de decisão

# %% [markdown]
# 4. avaliação
