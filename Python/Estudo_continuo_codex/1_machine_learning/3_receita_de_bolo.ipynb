# %% [markdown]
# ### Receita de bolo - árvore de decisão

# %% [markdown]
# ###### Objetivo:
# ###### Descobrir qual é o tipo de floresta
# ###### utilizando diversas características do terreno.
# #
# ###### Forest Cover Type
# #
# ###### Mais de 580 mil registros
# ###### 54 variáveis

# %% [markdown]
# ### Passo 1 - IMPORTAR AS BIBLIOTECAS

# %% [markdown]
# 1. Manipulação de dados

# %% [markdown]
# 2. Dividir treino e teste

# %% [markdown]
# 3. Modelo árvore de decisão

# %% [markdown]
# 4. avaliação

# %% [markdown]
# ### Passo 2 - IMPORTAR O DATASET

# %% [markdown]
# fetch_covtype baixa automaticamente

# %% [markdown]
# um grande dataset de florestas

# %% [markdown]
# ### Passo 3 - TRANSFORMAR O DATAFRAME

# %% [markdown]
# ### Passo 4 - VISUALIZAR O DATASET

# %% [markdown]
# ### PASSO 5 - TAMANHO DO DATASET

# %% [markdown]
# ### PASSO 6 - INFORMAÇÕES GERAIS

# %% [markdown]
# ### PASSO 7 - VERIFICAR DADOS NULOS

# %% [markdown]
# ### PASSO 8 - SEPARAR VARIÁVEIS

# %% [markdown]
# ##### X = características

# %% [markdown]
# ##### y = resposta

# %% [markdown]
# ### PASSO 9 - DIVIDIR TREINO E TESTE

# %% [markdown]
# ### PASSO 10 - CRIAR O MODELO

# %% [markdown]
# ### PASSO 11 - TREINAR

# %% [markdown]
# ### PASSO 12 - REALIZAR PREVISÕES

# %% [markdown]
# ### PASSO 13 - CALCULAR A ACURÁCIA

# %% [markdown]
# ### PASSO 14 - MATRIZ DE CONFUSÃO

# %% [markdown]
# ### PASSO 15 - RELATÓRIO DE CLASSIFICAÇÃO
