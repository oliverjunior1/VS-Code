# %%
import pandas as pd

# %% [markdown]
# ### Extract

# %%
vendas = pd.read_csv('vendas.csv')

# %% [markdown]
# ### Transform

# %%
vendas['valor'] = vendas['valor'].fillna(0)
vendas
# Out:
#     produto   valor
# 0  Notebook  3500.0
# 1     Mouse     0.0
# 2   Teclado   150.0
# 3   Monitor  1200.0
