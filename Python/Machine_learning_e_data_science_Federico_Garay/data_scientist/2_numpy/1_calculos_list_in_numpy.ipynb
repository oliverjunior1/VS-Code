# %% [markdown]
# ##### Monte uma lista e multiplique todos os números por 3 com numpy:

# %%
list = [20,25,30,35,40]

# %%
list*3
list
# Out:
# [20, 25, 30, 35, 40]

# %% [markdown]
# - You can see, it doesn't work.

# %%
import numpy as np

# %%
list_3 = np.array(list)*3
list_3
# Out:
# array([ 60,  75,  90, 105, 120])

# %%
list_3 = np.array(list)**(1/3)
list_3
# Out:
# array([2.71441762, 2.92401774, 3.10723251, 3.27106631, 3.41995189])

# %%
notas = [7, 8, 9, 10]
notas_medium = np.array(notas).mean()
notas_medium
# Out:
# np.float64(8.5)
