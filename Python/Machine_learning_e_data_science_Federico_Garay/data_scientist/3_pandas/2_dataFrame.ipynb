# %% [markdown]
# ### Exemplo 1: criando e visualizando dados

# %%
import pandas as pd

# %%
dados = {'produto':['Mouse', 'Teclado', 'Caderno', 'Caneta', 'Monitor'],
         'categoria':['Informática', 'Informática', 'Papelaria', 'Papelaria', 'Informática'],
         'preco':[50,120,25,5,900],
         'quantidade':[2,1,4,10,1]}

# %%
df = pd.DataFrame(dados)

# %%
df
# Out:
#    produto    categoria  preco  quantidade
# 0    Mouse  Informática     50           2
# 1  Teclado  Informática    120           1
# 2  Caderno    Papelaria     25           4
# 3   Caneta    Papelaria      5          10
# 4  Monitor  Informática    900           1

# %%
df.head()
# Out:
#    produto    categoria  preco  quantidade
# 0    Mouse  Informática     50           2
# 1  Teclado  Informática    120           1
# 2  Caderno    Papelaria     25           4
# 3   Caneta    Papelaria      5          10
# 4  Monitor  Informática    900           1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   produto     5 non-null      object
#  1   categoria   5 non-null      object
#  2   preco       5 non-null      int64
#  3   quantidade  5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes

# %% [markdown]
# ### Exemplo 2: filtrando e resumindo

# %%
dados = {
    'produto':['Mouse', 'Teclado', 'Caderno', 'Caneta', 'Monitor'],
    'categoria':['Informática','Informática', 'Papelaria', 'Papelaria', 'Informática'],
    'preco':[50,120,25,5,900],
    'quantidade':[2,1,4,10,1]
}

# %%
import pandas as pd

df = pd.DataFrame(dados)

# %%
df.head()
# Out:
#    produto    categoria  preco  quantidade
# 0    Mouse  Informática     50           2
# 1  Teclado  Informática    120           1
# 2  Caderno    Papelaria     25           4
# 3   Caneta    Papelaria      5          10
# 4  Monitor  Informática    900           1

# %% [markdown]
# ### Criando uma nova coluna

# %% [markdown]
# ### Filtrando, parecido com WHERE em SQL

# %% [markdown]
# ### Estatísticas simples

# %% [markdown]
# ### Agrupamento, parecido com GROUP BY em SQL
