# %% [markdown]
# ### Verificar versão

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.6.1

# %% [markdown]
# ### Dataset Exemplo

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'nome':['Joaquim', 'Alyne', 'Mariane', 'Pepe', 'Alycia'],
    'produtos':['notebook', 'maquiagem', 'batom', 'jogo', 'maquiagem'],
    'loja':['gamescore', 'beautiful', 'beautiful', 'gamescore', 'beautiful'],
    'valor':[9999.00, 9.99,1.99,9.99, 7.99]}

)

df.head()
# Out:
#       nome   produtos       loja
# 0  Joaquim   notebook  gamescore
# 1    Alyne  maquiagem  beautiful
# 2  Mariane      batom  beautiful
# 3     Pepe       jogo  gamescore

# %% [markdown]
# ### Separando variáveis

# %%
X = df[['produtos', 'loja']]

# %% [markdown]
# Target(y)

# %%
y = df['loja']
