# %% [markdown]
# ### Exemplo simples de Árvores de decisão

# %%
from sklearn import tree
import matplotlib.pyplot as plt

# %% [markdown]
# - Dados de exemplo (features)
# - Cada linha representa [peso, textura]
# - peso:1 = leve, 2 = pesado
# - textura: 1 = áspera, 2 = lisa

# %%
X = [[1,1],[2,1],[2,2],[1,2]]

# %% [markdown]
# # Classes (labels)

# %% [markdown]
# 0 = maçã, 1 = laranja

# %%
y = [0,1,1,0]

# %% [markdown]
# Criando o classificador

# %%
clf = tree.DecisionTreeClassifier()

# %% [markdown]
# Treinando o modelo

# %%
clf = clf.fit(X,y)

# %% [markdown]
# - Fazendo uma previsão
# - Exemplo: fruta com peso=2 e textura=2

# %%
plt.figure(figsize = (8,6))
tree.plot_tree(clf,
               feature_names=['peso', 'textura'],
               class_names=['maçã', 'laranja'],
               filled=True)

plt.show()

# %%
predicao = clf.predict([[2,2]])

# %%
print('Predicao: ', predicao)
# Out:
# Predicao:  [1]

# %% [markdown]
# - `x` são atributos (peso e textura).

# %% [markdown]
# - `y` são as classes (maçã ou laranja).

# %% [markdown]
# - O modelo aprende a separar os dados com base nesses atributos.

# %% [markdown]
# - Depois, usamos `predict` para prever a classe de uma nova entrada.

# %% [markdown]
# O que acontece aqui:
# - ``feature_names`` dá nomes às colunas (peso e textura).
#
# - ``class_names`` mostra os rótulos das classes (maçã e laranja).
#
# - `filled=True` colore os nós para facilitar a leitura.
#
# Assim você verá um gráfico com os nós da árvore, mostrando como ela decide entre maçã e laranja com base nos atributos.
