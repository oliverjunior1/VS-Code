# %% [markdown]
# ### Series

# %%
import pandas as pd

# %%
serie = pd.Series([5,10,15,20,25])

# %%
filtro = serie > 15
serie_filtrada = serie[filtro]
serie_filtrada
# Out:
# 3    20
# 4    25
# dtype: int64

# %%
filtro
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# dtype: bool
