# %% [markdown]
# Dada una serie de pandas llamada `serie_numerica` que contienga los números de tu preferencia.
#
# Realiza las siguientes operaciones matemáticas y guarda los resultados en variables separadas:
#
# 1. Multiplica `serie_numerica` por 2 y guarda el resultado en `serie_doble`.
#
# 2. Divide `serie_numerica` por 10 y guarda el resultado en `serie_dividida`.

# %%
import pandas as pd

serie_numerica = pd.Series([3,5,8,12,17,22])

serie_doble = 2*serie_numerica

serie_doble
# Out:
# 0     6
# 1    10
# 2    16
# 3    24
# 4    34
# 5    44
# dtype: int64

# %%
serie_dividida = serie_numerica/10

serie_dividida
# Out:
# 0    0.3
# 1    0.5
# 2    0.8
# 3    1.2
# 4    1.7
# 5    2.2
# dtype: float64
