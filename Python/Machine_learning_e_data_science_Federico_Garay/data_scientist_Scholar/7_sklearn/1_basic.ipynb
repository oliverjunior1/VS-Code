# %% [markdown]
# ### Verificar versão

# %%
import sklearn

print(sklearn.__version__)
# Out:
# 1.6.1

# %% [markdown]
# ### Dataset Exemplo

# %%
import pandas as pd

dados = pd.read_csv('clientes.csv')

print(dados.head())
# Out:
#    idade  salario  comprou
# 0     25     3000        0
# 1     30     4500        1
# 2     40     7000        1

# %% [markdown]
# ### Separando variáveis

# %%
X = dados[['idade', 'salario']]
