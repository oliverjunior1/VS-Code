# %% [markdown]
# ### Mini-projeto: previsão de clientes

# %%
# [idade, visitas_ao_site, recebeu_desconto]
X = [
    [19, 2, 0],
    [23, 5, 1],
    [27, 3, 0],
    [31, 8, 1],
    [36, 6, 1],
    [42, 2, 0],
    [47, 9, 1],
    [52, 7, 1],
    [58, 1, 0],
    [63, 4, 1],
]

y = [0, 1, 0, 1, 1, 0, 1, 1, 0, 0]

# %% [markdown]
# 1. Separar dados de treino e teste.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier

# %%
X_treino, y_treino, X_teste, y_teste = train_test_split(X, y, random_state=42, test_size=0.25)

# %% [markdown]
# 2. Treinar uma árvore de decisão.
