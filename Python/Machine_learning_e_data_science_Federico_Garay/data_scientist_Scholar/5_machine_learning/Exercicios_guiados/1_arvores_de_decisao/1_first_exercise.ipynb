# %% [markdown]
# 1. Prevendo aprovação.
# Crie um modelo usando:

# %%
# [horas_de_estudo, presença_percentual]
X = [
    [1, 50],
    [2, 60],
    [3, 70],
    [5, 80],
    [7, 90],
    [8, 95],
]

# 0 = reprovado, 1 = aprovado
y = [0, 0, 0, 1, 1, 1]

# %% [markdown]
# 1. Crie um ``DecisionTreeClassifier``.

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# 2. Treine-o com ``fit``.

# %% [markdown]
# 3. Preveja o resultado de um aluno com ``6`` horas de estudo e ``85%`` de presença.

# %% [markdown]
# 4. Treine apenas com os dados de treino.

# %% [markdown]
# 1. Separe treino e teste.
