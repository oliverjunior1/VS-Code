# %% [markdown]
# 1. Receba 5 notas.

# %%
x = 50,100,80,45,75

# %% [markdown]
# 2. Armazene em uma lista.

# %% [markdown]
# 3. Calcule:
# - média
# - maior nota
# - menor nota

# %% [markdown]
# 4. Informe se a turma foi:
# - Excelente (média ≥ 9)
# - Boa (média ≥ 7)
# - Regular (média ≥ 5)
# - Fraca (média < 5)
