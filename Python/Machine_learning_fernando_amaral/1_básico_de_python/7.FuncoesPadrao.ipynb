# %% [markdown]
# # Formação Cientista de Dados - Prof. Fernando Amaral
# Funções Padrão

# %%
#funções internas
print(abs(-200))
lst = [1,2,30,30,45]
print("Maior valor: ", max(lst))
print("Menor valor: ", min(lst))
print("Soma: ", sum(lst))
print("Arredondamento: ", round(2.34567,2))
# Out:
# 200
# Maior valor:  45
# Menor valor:  1
# Soma:  108
# Arredondamento:  2.35

# %%
#statistica
from statistics import *
print("Média: ", mean(lst))
print("Mediana: ", median(lst))
print("Moda: ", mode(lst))
# Out:
# Média:  21.6
# Mediana:  30
# Moda:  30

# %%
#desvio padrão da amostra
print("Desvio padrão: ", stdev(lst))
# Out:
# Desvio padrão:  19.346834366376324

# %%
#variancia da amostra
print("Variância: ", variance(lst))
# Out:
# Variância:  374.3

# %%
from numpy import *
a = random.random((8,8))
print(type(a))
print(a)
# Out:
# <class 'numpy.ndarray'>
# [[0.24301064 0.73980669 0.33226788 0.81125627 0.16155867 0.31853658
#   0.04978906 0.62777123]
#  [0.56832588 0.3852365  0.62350176 0.5112834  0.69332681 0.38881079
#   0.54770428 0.31454874]
#  [0.36553215 0.27332156 0.24244754 0.11635626 0.07994696 0.60168051
#   0.56720782 0.89693283]
#  [0.65778932 0.35786304 0.81711092 0.98513004 0.40873282 0.20972816
#   0.25527845 0.77232477]
#  [0.57989687 0.39533942 0.48172197 0.80300746 0.39379492 0.12400616
#   0.10782177 0.49015243]
#  [0.22869228 0.5521774  0.35963456 0.75820856 0.22413367 0.15029133
#   0.43936669 0.47963695]
#  [0.64179558 0.25242547 0.15782097 0.1728403  0.63968476 0.24709491
#   0.04537271 0.31770442]
#  [0.50700801 0.74452617 0.60630661 0.773289   0.5399537  0.02214041
#   0.36966369 0.29763926]]
