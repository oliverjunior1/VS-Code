# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'cidade': ['São Paulo  ', 'Rio de Janeiro ', 'Belo Horizonte ']})

df
# Out:
#             cidade
# 0      São Paulo
# 1  Rio de Janeiro
# 2  Belo Horizonte

# %% [markdown]
# 1. Remover os espaços extras

# %%
df['cidade'] = df['cidade'].str.strip()

# %% [markdown]
# 2. Converter tudo para MAIÚSCULO

# %% [markdown]
# 3. Converter tudo para minúsculo
