# %% [markdown]
# ### Problema 1 — Valores Nulos
#
# Crie o DataFrame:

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
    'nome':['Ana', 'Pedro', np.nan, 'Maria'],
    'idade':[20, np.nan, 35, 40]
})

# %% [markdown]
# 1. Mostrar quantidade de nulos por coluna.

# %%
df.isnull().sum()
# Out:
# nome     1
# idade    1
# dtype: int64

# %% [markdown]
# 2. Mostrar porcentagem de nulos.

# %%
percrentual_nulos = (df.isnull().sum().sum()/df.size)*100
percrentual_nulos
# Out:
# np.float64(25.0)

# %% [markdown]
# 3. Substituir idade nula pela média.

# %%
df['idade'] = df['idade'].fillna(df['idade'].mean())
df
# Out:
#     nome      idade
# 0    Ana  20.000000
# 1  Pedro  31.666667
# 2    NaN  35.000000
# 3  Maria  40.000000

# %% [markdown]
# 4. Remover linhas onde nome é nulo.

# %%
df['nome'] = df['nome'].dropna()
df['nome']
# Out:
# 0      Ana
# 1    Pedro
# 2      NaN
# 3    Maria
# Name: nome, dtype: object
