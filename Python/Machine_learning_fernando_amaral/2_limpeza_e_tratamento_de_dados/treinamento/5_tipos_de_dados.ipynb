# %% [markdown]
# ### Tipos de dados

# %% [markdown]
# dataset:

# %%
import pandas as pd

df = pd.DataFrame({
    'idade': ['20','30','40'],
    'salario': ['1000','2500','3000']
})

df
# Out:
#   idade salario
# 0    20    1000
# 1    30    2500
# 2    40    3000

# %% [markdown]
# 1. Verificar os tipos das colunas.

# %%
df.dtypes
# Out:
# idade      object
# salario    object
# dtype: object

# %% [markdown]
# - Os tipos de dados das colunas

# %% [markdown]
# - Explorando as informações sobre o dataset

# %% [markdown]
# 2. Converter ``idade`` para inteiro.

# %% [markdown]
# 3. Converter ``salario`` para inteiro.

# %% [markdown]
# 4. Calcular a média do salário.

# %% [markdown]
# 5. Mostrar os tipos novamente para confirmar a conversão.
