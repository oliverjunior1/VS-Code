# %% [markdown]
# ### Padronização de Texto

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'sexo':['M', 'Masculino', 'm', 'F', 'feminino', 'F']
})
df
# Out:
#         sexo
# 0          M
# 1  Masculino
# 2          m
# 3          F
# 4   feminino
# 5          F

# %% [markdown]
# ### Transformar a coluna para ficar exatamente assim:

# %% [markdown]
# Feminino
# Feminino
# Feminino
# Masculino
# Masculino
# Masculino

# %% [markdown]
# 1. Mostre quais os tipos diferentes de characteres há

# %%
df['sexo'].unique()
# Out:
# array(['M', 'Masculino', 'm', 'F', 'feminino'], dtype=object)

# %% [markdown]
# 2. Mostre quantos caracteres diferentes há por tipo:

# %%
df['sexo'].value_counts()
# Out:
# sexo
# F            2
# M            1
# Masculino    1
# m            1
# feminino     1
# Name: count, dtype: int64
