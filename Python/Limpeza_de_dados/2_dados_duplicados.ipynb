# %% [markdown]
# ### Importar pacotes

# %%
import pandas as pd

# %% [markdown]
# ### Criar o dataset

# %%
df = pd.DataFrame({
    'cliente': ['A','B','B','C','D','D'],
    'valor': [10,20,20,30,40,40]
})

# %% [markdown]
# 1. Identificar duplicados.

# %% [markdown]
# 2. Contar quantos existem.
