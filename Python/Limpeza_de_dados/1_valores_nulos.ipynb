# %% [markdown]
# ### Importar os pacotes:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Criar o dataframe

# %%
df = pd.DataFrame({
    'nome': ['Ana', 'Pedro', np.nan, 'Maria'],
    'idade': [20, np.nan, 35, 40]
})
