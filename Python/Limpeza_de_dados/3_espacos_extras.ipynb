# %% [markdown]
# ### Importar os pacotes

# %%
import pandas as pd

# %% [markdown]
# ### Criar o dataset

# %%
df = pd.DataFrame({
    'cidade': [' São Paulo ','Rio de Janeiro ',' Belo Horizonte']
})

# %% [markdown]
# 1. Remover espaços.

# %% [markdown]
# 2. Converter para maiúsculo.
