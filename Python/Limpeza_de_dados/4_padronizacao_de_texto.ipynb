# %% [markdown]
# ### Importar os pacotes

# %%
import pandas as pd

# %% [markdown]
# ### Montar o dataset

# %%
df = pd.DataFrame({
    'sexo':['M', 'Masculino', 'm', 'F', 'feminino', 'F']
})

# %% [markdown]
# 1. Olhar como está o dataset

# %%
df
# Out:
#         sexo
# 0          M
# 1  Masculino
# 2          m
# 3          F
# 4   feminino
# 5          F

# %% [markdown]
# 2. Contar quantos valores diferentes há

# %%
df['sexo'].unique()
# Out:
# array(['M', 'Masculino', 'm', 'F', 'feminino'], dtype=object)

# %% [markdown]
# 3. Transformar a coluna para ficar apenas Feminino e Masculino
