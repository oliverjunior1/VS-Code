# %% [markdown]
# ### Atividade 1: Primeiro contato com dados

# %%
import pandas as pd

# %%
idades = [18, 22, 25, 30, 35]

# %%
df = pd.DataFrame(idades)

# %%
df.mean()
# Out:
# 0    26.0
# dtype: float64
