# %% [markdown]
# # Treinamento de Limpeza de Dados com Python e Pandas
#
# Este notebook reúne **30 exercícios práticos de limpeza de dados**, divididos em:
#
# - 🟢 **10 iniciantes** — problemas comuns de qualidade e preparação.
# - 🟡 **10 intermediários** — regras de negócio, inconsistências e transformações.
# - 🔴 **10 avançados** — detecção robusta de anomalias, duplicidades, datas, texto, categóricas e pipelines.
#
# ## Como treinar
#
# Para cada exemplo:
#
# 1. Leia o problema.
# 2. Execute a célula que cria os dados "sujos".
# 3. Tente resolver sozinho antes de olhar a solução.
# 4. Execute a solução.
# 5. Confira o resultado.
# 6. Tente adaptar a regra para outro cenário.
#
# > **Importante:** os dados são sintéticos e foram criados para treinamento. Em dados reais, sempre investigue a origem do problema antes de simplesmente apagar ou substituir valores.

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns",50)
pd.set_option("display.max_rows",100)

print("Pandas:", pd.__version__)
# Out:
# Pandas: 2.2.3

# %% [markdown]
# # Treinamento de Limpeza de Dados com Python e Pandas
#
# Este notebook reúne **30 exercícios práticos de limpeza de dados**, divididos em:
#
# - 🟢 **10 iniciantes** — problemas comuns de qualidade e preparação.
# - 🟡 **10 intermediários** — regras de negócio, inconsistências e transformações.
# - 🔴 **10 avançados** — detecção robusta de anomalias, duplicidades, datas, texto, categóricas e pipelines.
#
# ## Como treinar
#
# Para cada exemplo:
#
# 1. Leia o problema.
# 2. Execute a célula que cria os dados "sujos".
# 3. Tente resolver sozinho antes de olhar a solução.
# 4. Execute a solução.
# 5. Confira o resultado.
# 6. Tente adaptar a regra para outro cenário.
#
# > **Importante:** os dados são sintéticos e foram criados para treinamento. Em dados reais, sempre investigue a origem do problema antes de simplesmente apagar ou substituir valores.

# %%
df = pd.DataFrame({
    'Cliente': ["Ana", "Bruno", "Carla", "Diego"],
    "idade":[25, np.nan, 31, np.nan]
})
df
# Out:
#   Cliente  idade
# 0     Ana   25.0
# 1   Bruno    NaN
# 2   Carla   31.0
# 3   Diego    NaN
