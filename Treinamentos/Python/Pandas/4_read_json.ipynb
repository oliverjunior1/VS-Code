# %% [markdown]
# ### Read Json

# %%
import pandas as pd

# %%
df = pd.read_json('data.json')

df
# Out:
#                                              pokemons
# 0   {'id': 1, 'name': 'Bulbasaur', 'type': ['Grass...
# 1   {'id': 2, 'name': 'Ivysaur', 'type': ['Grass',...
# 2   {'id': 3, 'name': 'Venusaur', 'type': ['Grass'...
# 3   {'id': 4, 'name': 'Charmander', 'type': ['Fire']}
# 4   {'id': 5, 'name': 'Charmeleon', 'type': ['Fire']}
# ..                                                ...
# 94  {'id': 95, 'name': 'Onix', 'type': ['Rock', 'G...
# 95  {'id': 96, 'name': 'Drowzee', 'type': ['Psychi...
# 96   {'id': 97, 'name': 'Hypno', 'type': ['Psychic']}
# 97    {'id': 98, 'name': 'Krabby', 'type': ['Water']}
# 98      {'id': 99, 'name': 'King', 'type': ['Water']}
#
# [99 rows x 1 columns]
